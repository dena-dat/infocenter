# %%
# INSTALLATION
import pandas as pd
import numpy as np
import openpyxl
import requests
from io import BytesIO
from io import StringIO
from datetime import date, datetime, timezone, timedelta
# !pip install datawrapper
from datawrapper import Datawrapper
# Out:
# Collecting datawrapper
#   Downloading datawrapper-0.6.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from datawrapper) (8.7.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from datawrapper) (13.9.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from datawrapper) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datawrapper) (2.2.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from datawrapper) (7.34.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->datawrapper) (3.23.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->datawrapper) (75.2.0)
# Collecting jedi>=0.16 (from ipython->datawrapper)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->datawrapper) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->datawrapper) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->datawrapper) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->datawrapper) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->datawrapper) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->datawrapper) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->datawrapper) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->datawrapper) (4.9.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datawrapper) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datawrapper) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datawrapper) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datawrapper) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->datawrapper) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->datawrapper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->datawrapper) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->datawrapper) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->datawrapper) (3.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->datawrapper) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->datawrapper) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->datawrapper) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->datawrapper) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datawrapper) (1.17.0)
# Downloading datawrapper-0.6.1-py3-none-any.whl (14 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 33.4 MB/s eta 0:00:00
# Installing collected packages: jedi, datawrapper
# Successfully installed datawrapper-0.6.1 jedi-0.19.2

# %%
# Basis-URL für die Excel-Dateien
base_url = "https://public.eex-group.com/eex/eua-auction-report/emission-spot-primary-market-auction-report-{year}-data.xlsx"

# Aktuelles Jahr abrufen
current_year = datetime.now().year

# Erstes Jahr festlegen
first_year = 2021

# Liste für die Datenframes
dfs = []

# Loop über die Jahre
for year in range(current_year, first_year - 1, -1):
    # URL für das aktuelle Jahr erstellen
    current_url = base_url.format(year=year)

    # Überprüfen, ob die URL existiert
    response = requests.head(current_url)
    if response.status_code == 200:
        # Excel-Datei herunterladen
        response = requests.get(current_url)
        excel_data = BytesIO(response.content)

        # Daten aus Excel-Datei einlesen
        current_df = pd.read_excel(excel_data, header=5, engine='openpyxl')

        # Datenframe zur Liste hinzufügen
        dfs.append(current_df)

# Datenframes zusammenführen
df = pd.concat(dfs, ignore_index=True)

# Filtern der Daten
df = df[df["Auction Name"] == "Auction 4. Period DE"]

# Auswahl relevanter Spalten auswählen
df = df[["Date", "Auction Price €/tCO2", "Minimum Bid €/tCO2", "Maximum Bid €/tCO2"]]

# Umbenennen der Spalten
df = df.rename(columns={
    "Date": "Datum",
    "Auction Price €/tCO2": "Auktionspreis €/tCO2",
    "Minimum Bid €/tCO2": "Minimalgebot €/tCO2",
    "Maximum Bid €/tCO2": "Maximalgebot t/CO2"
})

# Aktuelles Datum und Uhrzeit
now = datetime.now()

# Berechnung des Datums vor zwei Jahren
two_years_ago = now - timedelta(days=2*365)

# Festlegen des ersten Tages des Monats vor zwei Jahren
start_date = two_years_ago.replace(day=1)

# Umwandlung der Spalte "Datum" in ein Datetime-Objekt
df['Datum'] = pd.to_datetime(df['Datum'], format='%Y-%m-%d')

# Formatierung des Zeitstempels
timestamp = now.strftime('%y%m%d')

print(df)

# Update des Charts
CHART_ID = "7MO47"
dw.add_data(chart_id=CHART_ID, data=df)
dw.publish_chart(chart_id=CHART_ID, display=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           Datum  Auktionspreis €/tCO2  Minimalgebot €/tCO2  Maximalgebot t/CO2
# 0    2025-07-04                 70.85                68.00               120.0
# 4    2025-06-27                 69.40                66.99                73.0
# 9    2025-06-20                 71.97                68.99                85.0
# 13   2025-06-13                 75.36                64.00                85.0
# 17   2025-06-06                 72.30                64.00                82.0
# ...         ...                   ...                  ...                 ...
# 983  2021-02-26                 37.51                36.66                44.0
# 988  2021-02-19                 38.36                36.80                44.0
# 993  2021-02-12                 37.80                32.02                45.0
# 998  2021-02-05                 37.61                34.00                41.0
# 1003 2021-01-29                 33.51                32.40                35.0
#
# [207 rows x 4 columns]
# {'data': {'publicId': '7MO47',
#   'language': 'de-DE',
#   'theme': 'dena',
#   'id': '7MO47',
#   'type': 'd3-lines',
#   'title': ' Auktionspreise für CO₂-Emissionsberechtigungen',
#   'lastEditStep': 5,
#   'publishedAt': '2025-07-07T08:02:16.660Z',
#   'publicUrl': 'https://datawrapper.dwcdn.net/7MO47/114/',
#   'publicVersion': 114,
#   'deleted': False,
#   'forkable': False,
#   'isFork': False,
#   'metadata': {'data': {'changes': [{'id': '1c1c1c1c1c',
#       'row': 0,
#       'time': 1695903547136,
#       'value': 'Auktionspreis €/tCO2',
#       'column': 6,
#       'ignored': False,
#       'previous': 'Auction Price €/tCO2'},
#      {'id': '1d1d1d1d1d',
#       'row': 0,
#       'time': 1695903563562,
#       'value': 'Minimalgebot €/tCO2',
#       'column': 7,
#       'ignored': False,
#       'previous': 'Minimum Bid €/tCO2'},
#      {'id': '1e1e1e1e1e',
#       'row': 0,
#       'time': 1695903590957,
#       'value': 'Maximalgebot €/tCO2',
#       'column': 8,
#       'ignored': False,
#       'previous': 'Maximum Bid €/tCO2'},
#      {'id': '1f1f1f1f1f',
#       'row': 0,
#       'time': 1697536069699,
#       'value': 'Auktionspreis €/tCO2',
#       'column': 2,
#       'ignored': False,
#       'previous': 'Auction Price €/tCO2'},
#      {'id': '1g1g1g1g1g',
#       'row': 0,
#       'time': 1697536079871,
#       'value': 'Minimalgebot €/tCO2',
#       'column': 3,
#       'ignored': False,
#       'previous': 'Minimum Bid €/tCO2'},
#      {'id': '1h1h1h1h1h',
#       'row': 0,
#       'time': 1697536086159,
#       'value': 'Maximalgebot €/tCO2',
#       'column': 4,
#       'ignored': False,
#       'previous': 'Maximum Bid €/tCO2'},
#      {'id': '1i1i1i1i1i',
#       'row': 0,
#       'time': 1701256026490,
#       'value': 'Auktionspreis',
#       'column': 1,
#       'ignored': False,
#       'previous': 'Auction Price €/tCO2'},
#      {'id': '1j1j1j1j1j',
#       'row': 0,
#       'time': 1701256034658,
#       'value': 'Mindestgebot',
#       'column': 2,
#       'ignored': False,
#       'previous': 'Minimum Bid €/tCO2'},
#      {'id': '1k1k1k1k1k',
#       'row': 0,
#       'time': 1701256039385,
#       'value': 'Maximalgebot',
#       'column': 3,
#       'ignored': False,
#       'previous': 'Maximum Bid €/tCO2'}],
#     'transpose': False,
#     'vertical-header': True,
#     'horizontal-header': True,
#     'column-format': {'X.1': {'type': 'auto',
#       'ignore': True,
#       'number-append': '',
#       'number-format': 'auto',
#       'number-divisor': 0,
#       'number-prepend': ''},
#      'Time': {'type': 'auto',
#       'ignore': True,
#       'number-append': '',
#       'number-format': 'auto',
#       'number-divisor': 0,
#       'number-prepend': ''},
#      'Status': {'type': 'auto',
#       'ignore': True,
#       'number-append': '',
#       'number-format': 'auto',
#       'number-divisor': 0,
#       'number-prepend': ''},
#      'Country': {'type': 'auto', 'ignore': True},
#      'Contract': {'type': 'auto',
#       'ignore': True,
#       'number-append': '',
#       'number-format': 'auto',
#       'number-divisor': 0,
#       'number-prepend': ''},
#      'Italy (IT)': {'type': 'auto', 'ignore': True},
#      'Malta (MT)': {'type': 'auto', 'ignore': True},
#      'Spain (ES)': {'type': 'auto', 'ignore': True},
#      'Cover Ratio': {'type': 'auto', 'ignore': True},
#      'Cyprus (CY)': {'type': 'auto', 'ignore': True},
#      'France (FR)': {'type': 'auto', 'ignore': True},
#      'Greece (EL)': {'type': 'auto', 'ignore': True},
#      'Latvia (LV)': {'type': 'auto', 'ignore': True},
#      'MS RRF (MX)': {'type': 'auto', 'ignore': True},
#      'Norway (NO)': {'type': 'auto', 'ignore': True},
#      'Poland (PL)': {'type': 'auto', 'ignore': True},
#      'Sweden (SE)': {'type': 'auto', 'ignore': True},
#      'Auction Name': {'type': 'auto',
#       'ignore': True,
#       'number-append': '',
#       'number-format': 'auto',
#       'number-divisor': 0,
#       'number-prepend': ''},
#      'Austria (AT)': {'type': 'auto', 'ignore': True},
#      'Belgium (BE)': {'type': 'auto', 'ignore': True},
#      'Croatia (HR)': {'type': 'auto', 'ignore': True},
#      'Denmark (DK)': {'type': 'auto', 'ignore': True},
#      'Estonia (EE)': {'type': 'auto', 'ignore': True},
#      'Finland (FI)': {'type': 'auto', 'ignore': True},
#      'Germany (DE)': {'type': 'auto', 'ignore': True},
#      'Hungary (HU)': {'type': 'auto', 'ignore': True},
#      'Iceland (IS)': {'type': 'auto', 'ignore': True},
#      'Ireland (IE)': {'type': 'auto', 'ignore': True},
#      'Romania (RO)': {'type': 'auto', 'ignore': True},
#      'Bulgaria (BG)': {'type': 'auto', 'ignore': True},
#      'Mean €/tCO2': {'type': 'auto', 'ignore': True},
#      'Portugal (PT)': {'type': 'auto', 'ignore': True},
#      'Slovakia (SK)': {'type': 'auto', 'ignore': True},
#      'Slovenia (SI)': {'type': 'auto', 'ignore': True},
#      'Lithuania (LT)': {'type': 'auto', 'ignore': True},
#      'Luxembourg (LU)': {'type': 'auto', 'ignore': True},
#      'Median €/tCO2': {'type': 'auto', 'ignore': True},
#      'Average bid size': {'type': 'auto', 'ignore': True},
#      'Netherlands (NL)': {'type': 'auto', 'ignore': True},
#      'InnoFund RRF (IX)': {'type': 'auto', 'ignore': True},
#      'Total Revenue €': {'type': 'auto', 'ignore': True},
#      'Liechtenstein (LI)': {'type': 'auto', 'ignore': True},
#      'Auction Volume tCO2': {'type': 'auto', 'ignore': True},
#      'Czech Republic (CZ)': {'type': 'auto', 'ignore': True},
#      'Innovation Fund (IF)': {'type': 'auto', 'ignore': True},
#      'Maximum Bid €/tCO2': {'type': 'auto', 'ignore': False},
#      'Minimum Bid €/tCO2': {'type': 'auto', 'ignore': False},
#      'Total Amount of Bids': {'type': 'auto', 'ignore': True},
#      'Northern Ireland (XI)': {'type': 'auto', 'ignore': True},
#      'Modernisation Fund (MF)': {'type': 'auto', 'ignore': True},
#      'Total Number of Bidders': {'type': 'auto', 'ignore': True},
#      'Number of bids submitted': {'type': 'auto', 'ignore': True},
#      'Number of successful bids': {'type': 'auto', 'ignore': True},
#      'Number of Successful Bidders': {'type': 'auto', 'ignore': True},
#      'Average volume bid per bidder': {'type': 'auto', 'ignore': True},
#      'Average volume won per bidder': {'type': 'auto', 'ignore': True},
#      'Average number of bids per bidder': {'type': 'auto', 'ignore': True},
#      'Standard deviation of bid volume per bidder': {'type': 'auto',
#       'ignore': True},
#      'Standard deviation of volume won per bidder': {'type': 'auto',
#       'ignore': True}},
#     'external-data': 'https://raw.githubusercontent.com/anneberner/Tabellen_duke/main/em_preise_euets_m.csv',
#     'upload-method': 'copy',
#     'use-datawrapper-cdn': False},
#    'describe': {'source-name': 'EEX',
#     'source-url': 'https://www.eex.com/de/marktdaten/umweltprodukte/eu-ets-auktionen',
#     'intro': 'in Euro/tCO₂',
#     'byline': 'dena',
#     'aria-description': '',
#     'number-format': '-',
#     'number-divisor': 0,
#     'number-append': '',
#     'number-prepend': '',
#     'hide-title': False},
#    'visualize': {'dark-mode-invert': True,
#     'highlighted-series': [],
#     'highlighted-values': [],
#     'sharing': {'enabled': False,
#      'url': 'https://www.datawrapper.de/_/7MO47',
#      'auto': False},
#     'lines': {'Maximum Bid €/tCO2': {'width': 'style3', 'directLabel': False},
#      'Minimum Bid €/tCO2': {'width': 'style3', 'directLabel': False},
#      'Auction Price €/tCO2': {'directLabel': False,
#       'valueLabels': {'first': False, 'showCircles': False}}},
#     'x-grid': 'off',
#     'y-grid': 'on',
#     'scale-y': 'linear',
#     'sort-by': 'first',
#     'category': 'direct',
#     'overlays': [],
#     'color-key': True,
#     'base-color': '#dbdcdd',
#     'grid-lines': 'show',
#     'sort-areas': 'keep',
#     'bar-padding': 60,
#     'label-space': 30,
#     'sort-values': False,
#     'stack-areas': True,
#     'valueLabels': {'show': 'hover', 'enabled': True, 'placement': 'outside'},
#     'yAxisLabels': {'enabled': True,
#      'alignment': 'left',
#      'placement': 'outside'},
#     'area-opacity': 0.5,
#     'custom-range': ['', ''],
#     'custom-ticks': '',
#     'disable-tabs': True,
#     'grid-lines-x': {'type': 'ticks', 'enabled': False},
#     'label-colors': False,
#     'label-margin': 0,
#     'stack-to-100': False,
#     'totalsLabels': False,
#     'interpolation': 'linear',
#     'negativeColor': {'enabled': False},
#     'reverse-order': False,
#     'rotate-labels': 'auto',
#     'show-tooltips': True,
#     'x-grid-format': 'YYYY',
#     'x-tick-format': '',
#     'y-grid-format': 'auto',
#     'y-grid-labels': 'auto',
#     'absolute-scale': False,
#     'categoryLabels': {'enabled': True, 'position': 'direct'},
#     'chart-type-set': True,
#     'color-category': {'map': {'Maximum Bid €/tCO2': '#dbdcdd',
#       'Minimum Bid €/tCO2': '#dbdcdd',
#       'Auction Price €/tCO2': '#a9aaab'}},
#     'custom-range-x': ['', ''],
#     'custom-range-y': ['', ''],
#     'custom-ticks-x': '2021, 2022,2023, 2024',
#     'custom-ticks-y': '',
#     'plotHeightMode': 'fixed',
#     'series-padding': 60,
#     'show-color-key': False,
#     'variate-colors': False,
#     'connector-lines': True,
#     'plotHeightFixed': 339,
#     'plotHeightRatio': 0.5,
#     'text-annotations': [{'bg': False,
#       'dx': -68,
#       'dy': 7,
#       'id': '1c1c1c1c1c',
#       'bold': False,
#       'size': 11,
#       'text': 'Maximalangebot',
#       'align': 'mc',
#       'color': False,
#       'width': 25,
#       'italic': False,
#       'position': {'x': '2023/03/31 16:02', 'y': '126.4720'},
#       'underline': False,
#       'showMobile': True,
#       'showDesktop': True,
#       'connectorLine': {'type': 'curveRight',
#        'circle': False,
#        'stroke': 1,
#        'enabled': True,
#        'arrowHead': 'lines',
#        'circleStyle': 'solid',
#        'circleRadius': 15,
#        'inheritColor': False,
#        'targetPadding': 4},
#       'mobileFallback': False},
#      {'bg': False,
#       'dx': 56,
#       'dy': 29,
#       'id': '1d1d1d1d1d',
#       'bold': False,
#       'size': 11,
#       'text': 'Minimalangebot ',
#       'align': 'mc',
#       'color': False,
#       'width': 25,
#       'italic': False,
#       'position': {'x': '2022/07/14 22:25', 'y': '44.3003'},
#       'underline': False,
#       'showMobile': True,
#       'showDesktop': True,
#       'connectorLine': {'type': 'curveRight',
#        'circle': False,
#        'stroke': 1,
#        'enabled': True,
#        'arrowHead': 'lines',
#        'circleStyle': 'solid',
#        'circleRadius': 15,
#        'inheritColor': False,
#        'targetPadding': 4},
#       'mobileFallback': False}],
#     'tooltip-x-format': 'll',
#     'y-grid-subdivide': True,
#     'custom-area-fills': [{'id': '1c1c1c1c1c',
#       'to': 'Minimum Bid €/tCO2',
#       'from': 'Auction Price €/tCO2',
#       'color': '#dbdcdd',
#       'opacity': 0.2,
#       'colorNegative': '#E31A1C',
#       'useMixedColors': False},
#      {'id': '1d1d1d1d1d',
#       'to': 'Maximum Bid €/tCO2',
#       'from': 'Auction Price €/tCO2',
#       'color': '#dbdcdd',
#       'opacity': 0.2,
#       'colorNegative': '#E31A1C',
#       'interpolation': 'linear',
#       'useMixedColors': False}],
#     'range-annotations': [],
#     'value-label-colors': False,
#     'y-grid-label-align': 'left',
#     'value-labels-format': '0,0.[00]',
#     'area-separator-color': 0,
#     'area-separator-lines': False,
#     'tooltip-number-format': '0,0.[00]'},
#    'axes': {'x': 'Date', 'column': 'Auction Price €/tCO2'},
#    'publish': {'embed-width': 600,
#     'embed-height': 500,
#     'blocks': {'logo': {'id': 'dena', 'enabled': True},
#      'embed': False,
#      'download-pdf': False,
#      'download-svg': False,
#      'get-the-data': True,
#      'download-image': True},
#     'export-pdf': {},
#     'embed-codes': {'embed-method-responsive': '<iframe title=" Auktionspreise für CO₂-Emissionsberechtigungen" aria-label="Interactive line chart" id="datawrapper-chart-7MO47" src="https://datawrapper.dwcdn.net/7MO47/114/" scrolling="no" frameborder="0" style="width: 0; min-width: 100% !important; border: none;" height="500" data-external="1"></iframe><script type="text/javascript">!function(){"use strict";window.addEventListener("message",function(a){if(void 0!==a.data["datawrapper-height"]){var e=document.querySelectorAll("iframe");for(var t in a.data["datawrapper-height"])for(var r,i=0;r=e[i];i++)if(r.contentWindow===a.source){var d=a.data["datawrapper-height"][t]+"px";r.style.height=d}}})}();\n</script>',
#      'embed-method-iframe': '<iframe title=" Auktionspreise für CO₂-Emissionsberechtigungen" aria-label="Interactive line chart" id="datawrapper-chart-7MO47" src="https://datawrapper.dwcdn.net/7MO47/114/" scrolling="no" frameborder="0" style="border: none;" width="600" height="500" data-external="1"></iframe>',
#      'embed-method-web-component': '<div style="min-height:500px" id="datawrapper-vis-7MO47"><script type="text/javascript" defer src="https://datawrapper.dwcdn.net/7MO47/embed.js" charset="utf-8" data-target="#datawrapper-vis-7MO47"></script><noscript><img src="https://datawrapper.dwcdn.net/7MO47/full.png" alt="" /></noscript></div>'},
#     'autoDarkMode': False,
#     'chart-height': 369,
#     'force-attribution': False},
#    'annotate': {'notes': 'Preise bei der Primärauktion für Deutschland an der EEX'},
#    'custom': {'custom-field-1': ''}},
#   'externalData': '',
#   'utf8': False,
#   'createdAt': '2023-09-27T09:34:45.000Z',
#   'lastModifiedAt': '2025-07-07T08:02:16.660Z',
#   'forkedFrom': None,
#   'organizationId': 'HcOk2LR4',
#   'authorId': 839914,
#   'folderId': 199727,
#   'deletedAt': None},
#  'version': 114,
#  'url': 'https://datawrapper.dwcdn.net/7MO47/114/'}
